# %%
# ../utilities/util_path_ops
# Last modify: 20181001

# %% [markdown]
# ## Picking Out Components of a Path
# Ref: https://realpython.com/python-pathlib/ <br>
# The different parts of a path are conveniently available as properties. Basic examples include:
# <ul>
#     <li>.name: the file name without any directory</li>
#     <li>.parent: the directory containing the file, or the parent directory if path is a directory</li>
#     <li>.stem: the file name without the suffix</li>
#     <li>.suffix: the file extension</li>
#     <li>.anchor: the part of the path before the directories</li>
# </ul>

# %%
from os import mkdir
import pathlib

# %%
def dir_check (dir_check = None, dir_create = True, return_type = 'Bool'):
    print(f'===== util_dir_check/util_path_ops =====')
    
    if dir_check == None:
        raise ValueError("No directory for checking.")
        
    else:
        current_dir = pathlib.Path.cwd()
        proj_dir = current_dir.parent
        dir_to_check = proj_dir.joinpath(dir_check)
        dir_to_check_exist = False
        
        if dir_to_check.exists() :
            print (f'{dir_to_check} | exist, no action required.')
            dir_to_check_exist = True
        else:
            
            # Not contain extension, is a directory
            if len(dir_to_check.suffix) == 0 and dir_create == True:
                print (f'{dir_to_check} | exist, dir created.')
                mkdir(dir_to_check)
                dir_to_check_exist = True
            
            elif len(dir_to_check.suffix) == 0 and dir_create == False :
                print (f'{dir_to_check} | exist, dir not created according to config.')
                
            # Contains extension, Not a directory
            elif len(dir_to_check.suffix) != 0:
                raise ValueError(f'{dir_to_check} | file not exist.')
        
        if return_type == 'Bool':
            return dir_to_check_exist
        elif return_type == 'Path':
            return str(dir_to_check)

# %%
def display_dir_tree(directory):
    print(f'===== util_dir_check/display_dir_tree =====')
    print(f'+ {directory}')
    
    for path in sorted(directory.rglob('*')):
        depth = len(path.relative_to(directory).parts)
        spacer = '    ' * depth
        print(f'{spacer}+ {path.name}')

# %%
def main():
    print(dir_check('settings/abcccc', dir_create = False, return_type='Path'))
    print(dir_check('settings/abcccc', dir_create = False, return_type='Bool'))
    display_dir_tree(pathlib.Path.cwd().parent)

# %%
if __name__ == '__main__':
    main()
# Out:
# ===== util_dir_check/util_path_ops =====
# C:\Users\alana\AnacondaProjects\nous\settings\abcccc | exist, dir not created according to config.
# C:\Users\alana\AnacondaProjects\nous\settings\abcccc
# ===== util_dir_check/util_path_ops =====
# C:\Users\alana\AnacondaProjects\nous\settings\abcccc | exist, dir not created according to config.
# False
# ===== util_dir_check/display_dir_tree =====
# + C:\Users\alana\AnacondaProjects\nous
#     + .git
#         + COMMIT_EDITMSG
#         + config
#         + description
#         + FETCH_HEAD
#         + HEAD
#         + hooks
#             + applypatch-msg.sample
#             + commit-msg.sample
#             + fsmonitor-watchman.sample
#             + post-update.sample
#             + pre-applypatch.sample
#             + pre-commit.sample
#             + pre-push.sample
#             + pre-rebase.sample
#             + pre-receive.sample
#             + prepare-commit-msg.sample
#             + update.sample
#         + index
#         + info
#             + exclude
#         + logs
#             + HEAD
#             + refs
#                 + heads
#                     + master
#                 + remotes
#                     + origin
#                         + HEAD
#                         + master
#         + objects
#             + 12
#                 + 6c40f9514719bf1c51b0860e493d2b08ab8742
#             + 17
#                 + cd0aeb039a3088e9a6703fd2026c67743409e7
#                 + ef29f443414d6e7d1bfa0d1098c7847f4bc763
#             + 1e
#                 + af494943de08d1da44ba2c9f42d844985a8402
#             + 1f
#                 + 65c7072a695d123afc46004f2fd193b6fd9e09
#             + 23
#                 + 27ea498ab473b64cc4b08b4340e5e09ba80100
#             + 3a
#                 + be5951955ce6af2d9189a7a28a100e09b9184f
#             + 46
#                 + 14d32e82b2ad9a4cf6b338b6595dcbcdcd8256
#                 + 5d8f25d81e391f3d1909c51e32d729599db7e4
#                 + f6b5b62fb4e45dd8eb20376eeb3e8278936e13
#             + 57
#                 + 83279c4abc49d475ee39b1965283a3ac388f8f
#             + 73
#                 + 4ebb6979b85bb3d2790968395e9a40f071dd17
#             + 88
#                 + 467cc18bf923a371c9c94221bdf67ec3815163
#             + 97
#                 + f4817cb00a2047b792b7e0488089af697a5254
#             + 9a
#                 + 57adcdaaa62ea6a774b460b3fa9603a04dd661
#             + a6
#                 + 421ca1471550aea42597a90ff931995820503e
#                 + da12df981d4985f14e9aff062f54ff3ecc2dab
#             + ad
#                 + 0adc60a829986c9d25580f704349e5bb7c3bf4
#             + b4
#                 + 3819754105957e93f452822ee79142b7e705e9
#             + c1
#                 + 28c4ddbf4da269fc9f772f19170cc28e3c16a9
#             + d4
#                 + 5ce26555744abe1ad0d07498d7679487dc285f
#             + de
#                 + db07d0da8f99f7ed880de69f11e2959d2563b0
#             + e1
#                 + 083e84e6af89da3066c19e291f00d0cc0818fb
#             + ff
#                 + 4d288f36e0345033a6e3efa17700f079e3a1ee
#             + info
#             + pack
#         + ORIG_HEAD
#         + packed-refs
#         + refs
#             + heads
#                 + master
#             + remotes
#                 + origin
#                     + HEAD
#                     + master
#             + tags
#     + .ipynb_checkpoints
#     + inputs
#     + README.md
#     + settings
#         + config.json
#     + staging
#         + py_atm
#             + .vscode
#                 + launch.json
#                 + settings.json
#             + 00.Automate the Boring Stuff.url
#             + 00.RegexPhoneEmailScraper.py
#             + 13.List.py
#             + 14.LoopWithList.py
#             + 15.ListMethods.py
#             + 16.String_n_List.py
#             + 17-P.CharacterCount.py
#             + 17.Dictionary.py
#             + 18.DataStructure.py
#             + 19.AdvancedString.py
#             + 20.StringMethod.py
#             + 21.StringFormatting.py
#             + 22.Batch.bat
#             + 22.LauchPyOutsideIDLE.py
#             + 23.RegularExpressBasics.py
#             + 24.RegexGroups_PipeChar.py
#             + 25.RepetitionRegexPatterns_GreedyMatch.py
#             + 30.File_Folders.py
#             + 31.ReadWritePlainText.py
#             + 32.CopyMoveFiles.py
#             + 33.DeleteFile.py
#             + 34.WalkThruDirTree.py
#             + 35.RaiseAssertStatements.py
#             + 36.Logging.py
#             + 36.Logging.py.log
#             + 38.WebBrowser.py
#             + 38.WebBrowser.py.log
#             + 39.DownloadFromWeb.py
#             + 39.DownloadFromWeb.py.log
#             + 40.WebScraping.py
#             + 41.ControlBrower.py
#             + 42-43.SpreadsheetOp.py
#             + 48.ControlMouse.py
#             + 49.ControlKeyboard.py
#             + 50.ScreenshotImgRecognition.py
#             + bat
#                 + GoogleMapSearch.bat
#                 + PhoneEmailScraper.bat
#             + built-in function.py
#             + input
#                 + (by Value)ST370064_StockTake_Variance_v180502_1534.xls
#                 + (by Value)ST370064_StockTake_Variance_v180502_1534.xlsx
#                 + chrome_lift_btn.PNG
#                 + chrome_youtube_btn.PNG
#                 + DirTreeExample
#                     + A
#                         + A1
#                             + A1.txt
#                         + A2
#                             + A2.txt
#                     + B
#                     + C
#                         + C.txt
#                         + C1
#                             + C1.txt
#                 + vscode_About_btn.PNG
#                 + vscode_help_btn.PNG
#                 + vscode_ok_btn.PNG
#             + log
#                 + 35.RaiseAssertStatements.log
#             + output
#                 + RomeoAndJuliet.txt
#                 + screenshot.png
#                 + testoutput.xlsx
#             + py_atm - Shortcut.lnk
#             + try-except.py
#         + py_prg
#             + .ipynb_checkpoints
#                 + py_pandas_juptyer_nb_test-checkpoint.ipynb
#             + .vscode
#                 + launch.json
#             + csv_export.py
#             + extract_header.py
#             + input
#                 + MMS_SQL
#                     + sql_stores.sql
#                     + test.sql
#                 + STK_180619
#                     + STK427698_314_370148_20180619074314.dat
#                     + STK428092_314_370213_20180619074314.dat
#                     + STK428094_314_370221_20180619074314.dat
#                     + STK798909_315_000022_20180619074615.dat
#                     + STK798924_315_000088_20180619074615.dat
#                     + STK811212_315_370023_20180619074409.dat
#                     + STK811221_315_370031_20180619074409.dat
#                     + STK811231_315_370049_20180619074409.dat
#                     + STK811243_315_370064_20180619074409.dat
#                     + STK811251_315_370072_20180619074409.dat
#                     + STK811263_315_370080_20180619074409.dat
#                     + STK811269_315_370114_20180619074409.dat
#                     + STK811290_315_370122_20180619074409.dat
#                     + STK811298_315_370130_20180619074409.dat
#                     + STK811311_315_370148_20180619074409.dat
#                     + STK811337_315_370155_20180619074409.dat
#                     + STK811350_315_370163_20180619074409.dat
#                     + STK811387_315_370171_20180619074409.dat
#                     + STK811408_315_370189_20180619074409.dat
#                     + STK811427_315_370197_20180619074409.dat
#                     + STK811465_315_370205_20180619074409.dat
#                     + STK811477_315_370213_20180619074409.dat
#                     + STK811494_315_370221_20180619074409.dat
#                     + STK811523_315_378034_20180619074409.dat
#                     + STK811526_315_379024_20180619074409.dat
#                     + STK811554_315_379032_20180619074409.dat
#             + log
#             + MMS_DEV_query_export.bat
#             + MMS_PRD_query_export.bat
#             + oradb_query_export_MMS_DEV.py
#             + oradb_query_export_MMS_PRD.py
#             + output
#                 + BP03-A02-S31_STO370221_ClosingBOH_EOD25Jun18.xlsx
#                 + output_20180622_155525.xlsx
#                 + output_20180622_160532.xlsx
#                 + output_20180622_161242.xlsx
#                 + output_20180622_161347.xlsx
#                 + output_20180625_094114.xlsx
#                 + output_20180625_094254.xlsx
#                 + output_20180625_094548.xlsx
#                 + output_20180625_154408.xlsx
#                 + output_20180626_092916.xlsx
#                 + output_20180626_095136.xlsx
#                 + output_20180626_102454.xlsx
#                 + output_20180626_102920.xlsx
#                 + output_20180626_104551.xlsx
#                 + output_20180626_112215.xlsx
#                 + output_20180626_122317.xlsx
#                 + output_20180626_122651.xlsx
#                 + output_20180626_124016.xlsx
#                 + output_20180626_125146.xlsx
#                 + output_20180626_132246.xlsx
#                 + output_20180626_133734.xlsx
#                 + output_20180626_152409.xlsx
#                 + output_20180626_161606.xlsx
#                 + output_20180626_162328.xlsx
#                 + output_20180627_145816.xlsx
#                 + output_20180709_093609.xlsx
#                 + output_20180709_093722.xlsx
#                 + output_20180709_093912.xlsx
#                 + output_20180710_095711.xlsx
#                 + output_20180723_162734.xlsx
#                 + output_20180723_162840.xlsx
#                 + output_20180723_165633.xlsx
#                 + Summary_STK314_315_180619.xls
#             + output.csv
#             + output_20180814_120540.csv
#             + py_data_extract
#                 + .ipynb_checkpoints
#                     + py_data_extract_v2-checkpoint.ipynb
#                     + py_data_extraction-checkpoint.ipynb
#                     + py_data_extraction-Copy1-checkpoint.ipynb
#                     + py_data_extraction_oracle_only-checkpoint.ipynb
#                     + py_data_extraction_v180917-checkpoint.ipynb
#                     + py_data_transform-checkpoint.ipynb
#                 + config
#                     + config.json
#                     + config.json.from_clip_db_MMS_DEV
#                     + config.json.from_clip_db_MMS_PRD
#                     + config.json.from_delim_MMS_PRD
#                     + config.json.from_delim_MMS_SPRC
#                     + config.json.from_delim_MMS_UPC
#                     + config.json.from_fixLen_SMSALE_ILS
#                     + config.json.from_fixLen_VCM_ILS
#                     + config.json_bak
#                     + config.json_bak_20180928_174153626954
#                     + config_build.json
#                 + config_py_extract_v2.json
#                 + dist
#                     + config_py_extract_v2.json
#                     + py_data_extract_v2.exe
#                 + dist_py_data_extract_bak
#                     + config
#                         + config.json
#                     + input
#                         + All Stores.sql
#                         + Top 10000 Items.sql
#                     + log
#                     + output
#                     + py_data_extraction.exe
#                 + dist_py_db_ext_bak
#                     + config
#                         + config.json
#                     + input
#                         + All Stores.sql
#                         + SMPOS_STORE.sql
#                         + Top 10000 Items.sql
#                     + log
#                     + output
#                         + output_20180917_111728903603.xlsx
#                     + py_data_extraction.exe
#                 + input
#                     + 00 SQL - Shortcut.lnk
#                     + Interface
#                         + bak
#                             + DFG Test Scenarios.zip
#                         + CORE RECORD
#                             + PRD_to_PCMS
#                                 + A10020180923192611.PRD
#                                 + A10020180923192611.SPRC
#                                 + A10020180923192611.UPC
#                                 + bak
#                                     + A10020180808160610.PRD
#                                     + A10020180808160610_simplified.PRD
#                                     + test.PRD
#                         + SALE
#                             + ILS_from_SMSALE
#                                 + bak
#                                     + ILS_370148_20180919040343.txt.0000542561
#                                 + ILS_370148_20180919040530.txt.0000542562
#                             + ILS_from_VCM
#                                 + 911_Sale&Refund Weighed.txt
#                                 + 914_Sale&Refund Each(No Balance).txt
#                                 + 915_Sale&Refund Each(Balance).txt
#                                 + 916_Sale&Refund Each(Negative Balance).txt
#                                 + 917_Single Sale (Change Given).txt
#                                 + 918_Two Promotion Transaction.txt
#                                 + 919_Single Promotion Transaction.txt
#                     + Interface Spec
#                         + MMS-SRS-ILS-Interface_Mapping_v20180920.xlsx
#                         + PCMS-MMS-ILS-Interface_Mapping_20180910_v13.2.xlsx
#                         + PCMS-MMS-ILS-Interface_Mapping_20180910_v13.3.xlsx
#                         + Product_Master_Group POS_Interface_Mappings_V0.8.7_20180926.xlsx
#                         + Ref_PCMS-30.Technical-10.ILS - Shortcut.lnk
#                         + XML3 Product.3.114.html
#                 + log
#                 + output
#                 + py_data_extract_v2.ipynb
#                 + py_data_extract_v2.py
#                 + py_data_extract_v2.spec
#                 + py_data_extraction-Copy1.ipynb
#                 + py_data_extraction.ipynb
#                 + py_data_extraction.py
#                 + py_data_extraction.spec
#                 + py_data_extraction_bak180921.py
#                 + py_data_extraction_db_ext_only.py
#                 + py_data_extraction_oracle_only.ipynb
#                 + py_data_extraction_oracle_only.py
#                 + py_data_transform.ipynb
#                 + py_oradb_extract.bat
#                 + readme.txt
#             + py_gen_sql
#                 + .ipynb_checkpoints
#                     + py_gen_sql-checkpoint.ipynb
#                 + config
#                     + config.json
#                 + input
#                 + log
#                 + output
#                     + output_20180924_094433362193_batch_1.sql
#                     + output_20180924_094440416845_batch_2.sql
#                     + output_20180924_094448406629_batch_3.sql
#                     + output_20180924_094456450123_batch_4.sql
#                     + output_20180924_094503872064_batch_5.sql
#                     + output_20180924_094510624677_batch_6.sql
#                     + output_20180924_094518088854_batch_7.sql
#                     + output_20180924_094525819869_batch_8.sql
#                     + output_20180924_094533139084_batch_9.sql
#                     + output_20180924_094540962818_batch_10.sql
#                     + output_20180924_094549014519_batch_11.sql
#                     + output_20180924_094557496526_batch_12.sql
#                     + output_20180924_094605160774_batch_13.sql
#                     + output_20180924_094611440805_batch_14.sql
#                 + py_gen_sql.ipynb
#                 + py_gen_sql.py
#             + py_pandas.py
#             + py_pandas_juptyer_nb_test.ipynb
#             + test.py
#     + utilities
#         + .ipynb_checkpoints
#             + parse_config-checkpoint.ipynb
#             + Test-checkpoint.ipynb
#             + util_path_ops-checkpoint.ipynb
#         + __pycache__
#             + util_dir_check.cpython-36.pyc
#             + util_path_ops.cpython-36.pyc
#         + parse_config.ipynb
#         + Test.ipynb
#         + util_path_ops.ipynb
#         + util_path_ops.py
